# %%
import pandas as pd
import os

# %%
d_types = {'RespondentID':str, 'Zipcode':str}

# %%
geo_left = pd.read_csv(os.path.join('..', 'data', 'survey', '2015 on-board survey', 'geo_responses_Left_20201211-122631.txt'),
                       dtype=d_types,
                       header=None,
                       names=['RespondentID', 'confidence', 'lat', 'lng']
                           )

###Clean-up
geo_left['RespondentID'] = geo_left['RespondentID'].str.replace('[', '')
geo_left['lng'] = geo_left['lng'].str.replace(']', '')

idx = geo_left.groupby('RespondentID')['confidence'].transform(max) == geo_left['confidence']
geo_left_clean = geo_left[idx].drop_duplicates('RespondentID')

# %%
geo_dest = pd.read_csv(os.path.join('..', 'data', 'survey', '2015 on-board survey', 'geo_responses_Dest_20201211-125615.txt'),
                       dtype=d_types,
                       header=None,
                       names=['RespondentID', 'confidence', 'lat', 'lng']
                           )

###Clean-up
geo_dest['RespondentID'] = geo_dest['RespondentID'].str.replace('[', '')
geo_dest['lng'] = geo_dest['lng'].str.replace(']', '')

idx = geo_dest.groupby('RespondentID')['confidence'].transform(max) == geo_dest['confidence']
geo_dest_clean = geo_dest[idx].drop_duplicates('RespondentID')

# %%
survey_all = pd.read_excel(os.path.join('..', 'data', 'survey', '2015 on-board survey', '01052016_Data_Cleaning_19.xlsx'),
                       dtype=d_types
                      )

survey_all.columns = [x.rstrip() for x in survey_all.columns]

# %%
survey_all = pd.merge(survey_all,
                      geo_left_clean,
                      on='RespondentID',
                      how='left',
                     )

survey_all = pd.merge(survey_all,
                      geo_dest_clean,
                      on='RespondentID',
                      how='left',
                      suffixes=['_left', '_dest']
                     )

# %%
list(survey_all)
# Out:
# ['RespondentID',
#  'CollectorID',
#  'StartDate',
#  'EndDate',
#  'IP Address',
#  'Route',
#  'Route - In/Out Bound',
#  'Time - Hour',
#  'Time - Minute',
#  'Time - AM/PM',
#  'Time',
#  'Left From',
#  'Left Other',
#  'Left St No',
#  'Left St Name',
#  'Left Nearest Intersection',
#  'Left Name',
#  'To Bus Walked',
#  'To Bus Drove & parked a car',
#  'To Bus Dropped off by someone',
#  'To Bus Biked',
#  'To Bus Rode with someone who parked',
#  'To Bus- Other',
#  'To Bus Time (mins) Total Buses',
#  'Response',
#  'Final Destination',
#  'Destination-Other',
#  'Dest St No',
#  'Dest St Name',
#  'Dest Nearest Intersection',
#  'Dest Name',
#  'Dest Walk',
#  'Dest Drive a Car',
#  'Dest Pick up by someone',
#  'Dest Bike',
#  'Dest Ride with someone who parked',
#  'Dest Bus',
#  'Dest Time to Walk/ Bike (minutes)',
#  'Time Trip Began',
#  'Payment',
#  'How Often',
#  'How Long',
#  'Employment',
#  'Employment Other',
#  'Why-No other transport',
#  'Why-Fuel cost',
#  "Why-Don't like to drive",
#  "Why-Can't drive",
#  'Why-Other',
#  'Alternate Drive a car',
#  'Alternate Walk',
#  'Alternate Taxi',
#  'Alternate Bike',
#  'Alternate Ride with someone',
#  'Alternate Would not make the trip',
#  'Alternate Other',
#  'Zipcode',
#  'Sex',
#  'Age',
#  'Persons at Home',
#  'Hispanic',
#  'Race',
#  'Race Other',
#  'Birth Place',
#  'Language',
#  'English Competence',
#  'Internet Access',
#  'Smart Phone',
#  'Texting Phone',
#  'CARTA website',
#  'CARTA booklet',
#  'Times Free Press Newspaper',
#  'Poster on bus',
#  'Bus drivers/other CARTA empl',
#  'Social media',
#  'Radio',
#  'Television',
#  'Other passengers',
#  'Bus Info Other',
#  'Household Income',
#  'Cleanliness of this bus',
#  'Room on this bus',
#  'Personal safety while riding',
#  'Personal safety at a bus stop',
#  'Convenience of routes',
#  'Driver courtesy',
#  'Bus running on time',
#  'Travel time on bus',
#  'Fare price',
#  'Overall service',
#  'Service Most Needed',
#  'Service Most Needed-Other',
#  'Additional Comments',
#  'Surveyor',
#  'Number',
#  'confidence_left',
#  'lat_left',
#  'lng_left',
#  'confidence_dest',
#  'lat_dest',
#  'lng_dest']

# %%
survey = survey_all[[
        'RespondentID',
        'Route',
        'Route - In/Out Bound',
        'Left From',
        'Left Other',
        'Left St No',
        'Left St Name',
        'Left Nearest Intersection',
        'Left Name',
        'Final Destination',
        'Destination-Other',
        'Dest St No',
        'Dest St Name',
        'Dest Nearest Intersection',
        'Dest Name',
        'Zipcode',
    
        'confidence_left',
        'lat_left',
        'lng_left',
        'confidence_dest',
        'lat_dest',
        'lng_dest'
]]

# %%
report_side = 'Left'
geo_df = geo_left_clean

# report_side = 'Dest'
# geo_df = geo_dest_clean

conf_col = 'confidence_{}'.format(report_side.lower())
st = '{} St Name'.format(report_side)
intrs = '{} Nearest Intersection'.format(report_side)

print('{} Side Summary:'.format(report_side).upper())

print('Total records: ', '{:,.0f}'.format(len(survey)))
print('Records processed in Geocode: ', '{:,.0f}'.format(len(geo_df)))

pct8 = len(survey[survey[conf_col]>=8]) / len(survey)
print('Records with Geocode Confidence factor greater than 8: ', '{:,.0f}'.format(len(survey[survey[conf_col]>=8])),\
      '{0:.0%}'.format(pct8))

pctnot8 = len(survey[survey[conf_col]<8]) / len(survey)
print('Records with Geocode Confidence factor lower than 8: ', len(survey[survey[conf_col]<8]), '{0:.0%}'.format(pctnot8))

pct_nostreet = len(survey[survey[st].isna()]) / len(survey)
print('Records with no Street Name: ', len(survey[survey[st].isna()]), '{0:.0%}'.format(pct_nostreet))
print('Records with no Street Name and no Nearest Intersection: ',\
      len(survey[(survey[st].isna()) & (survey[intrs].isna())]))
# Out:
# LEFT SIDE SUMMARY:
# Total records:  1,885
# Records processed in Geocode:  1,717
# Records with Geocode Confidence factor greater than 8:  1,565 83%
# Records with Geocode Confidence factor lower than 8:  152 8%
# Records with no Street Name:  438 23%
# Records with no Street Name and no Nearest Intersection:  342

# %%
survey['Route'] = survey['Route']

survey.loc[survey['confidence_left']>=8, 'Geocode_result_left'] = 'pass'
survey.loc[survey['confidence_left']<8, 'Geocode_result_left'] = 'no_pass'
survey.loc[survey['confidence_left'].isna(), 'Geocode_result_left'] = 'insufficient_data'

survey.loc[survey['confidence_dest']>=8, 'Geocode_result_dest'] = 'pass'
survey.loc[survey['confidence_dest']<8, 'Geocode_result_dest'] = 'no_pass'
survey.loc[survey['confidence_dest'].isna(), 'Geocode_result_dest'] = 'insufficient_data'
# Out:
# C:\ProgramData\Anaconda3\envs\geocodenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\envs\geocodenv\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\ProgramData\Anaconda3\envs\geocodenv\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
survey
# Out:
#      RespondentID                 Route Route - In/Out Bound  \
# 0      4199326829  10- East Chattanooga             In Bound
# 1      4206052159  10- East Chattanooga             In Bound
# 2      4206066684  10- East Chattanooga             In Bound
# 3      4209630869    21- Golden Gateway            Out Bound
# 4      4209714464           8- Eastdale            Out Bound
# 5      4210021492         1- Alton Park             In Bound
# 6      4210049627         1- Alton Park            Out Bound
# 7      4210067701         1- Alton Park             In Bound
# 8      4210354314         1- Alton Park             In Bound
# 9      4215237302          9- East Lake             In Bound
# 10     4215249165  10- East Chattanooga            Out Bound
# 11     4215260812     4- Hamilton Place             In Bound
# 12     4215330903     4- Hamilton Place             In Bound
# 13     4215355676     4- Hamilton Place             In Bound
# 14     4215372861     4- Hamilton Place            Out Bound
# 15     4215570303     4- Hamilton Place            Out Bound
# 16     4215577569     4- Hamilton Place            Out Bound
# 17     4215582385     4- Hamilton Place            Out Bound
# 18     4215588760     4- Hamilton Place            Out Bound
# 19     4215595712     4- Hamilton Place             In Bound
# 20     4224050680   3- Enterprise South            Out Bound
# 21     4224069501          9- East Lake             In Bound
# 22     4224077756          9- East Lake            Out Bound
# 23     4224090296      6- East Brainerd            Out Bound
# 24     4224107560      6- East Brainerd            Out Bound
# 25     4224162421      6- East Brainerd            Out Bound
# 26     4224225821      6- East Brainerd            Out Bound
# 27     4224233703      6- East Brainerd            Out Bound
# 28     4224241695      6- East Brainerd            Out Bound
# 29     4224247689      6- East Brainerd            Out Bound
# ...           ...                   ...                  ...
# 1855   4297728338     4- Hamilton Place             In Bound
# 1856   4297729564     4- Hamilton Place             In Bound
# 1857   4297731399     4- Hamilton Place             In Bound
# 1858   4297732235     4- Hamilton Place             In Bound
# 1859   4297733946     4- Hamilton Place            Out Bound
# 1860   4297734825     4- Hamilton Place             In Bound
# 1861   4297740177     4- Hamilton Place            Out Bound
# 1862   4297741437     4- Hamilton Place            Out Bound
# 1863   4297742764     4- Hamilton Place             In Bound
# 1864   4297743963     4- Hamilton Place             In Bound
# 1865   4297744874     4- Hamilton Place            Out Bound
# 1866   4373614054     4- Hamilton Place             In Bound
# 1867   4384066347     4- Hamilton Place            Out Bound
# 1868   4401779443    21- Golden Gateway            Out Bound
# 1869   4401789442     5- North Brainerd            Out Bound
# 1870   4401804301  2- North Chattanooga             In Bound
# 1871   4401816904     4- Hamilton Place            Out Bound
# 1872   4401829568     4- Hamilton Place             In Bound
# 1873   4401845747     4- Hamilton Place             In Bound
# 1874   4401905125      14- Mocs Express             In Bound
# 1875   4401948444  10- East Chattanooga                  NaN
# 1876   4401964371    21- Golden Gateway             In Bound
# 1877   4401992306    21- Golden Gateway             In Bound
# 1878   4402010510    21- Golden Gateway            Out Bound
# 1879   4402023586                   NaN                  NaN
# 1880   4402033165           8- Eastdale                  NaN
# 1881   4402046595         1- Alton Park            Out Bound
# 1882   4402471196         1- Alton Park             In Bound
# 1883   4402483038          9- East Lake             In Bound
# 1884   4402502115  10- East Chattanooga                  NaN
#
#               Left From Left Other             Left St No      Left St Name  \
# 0                  Home        NaN                   3308   Campbell Street
# 1                  Home        NaN                    314   Riverside Drive
# 2                  Home        NaN                   3211   Campbell Street
# 3                  Home        NaN                    NaN          D. Drive
# 4                  Home        NaN                    NaN       Tunnel Blvd
# 5                  Home        NaN                    NaN         West Main
# 6                  Home        NaN                   2459        5th Avenue
# 7                  Home        NaN                   4429             Fagan
# 8                  Home        NaN                   1230   Grove Street Ct
# 9                  Home        NaN                    NaN               NaN
# 10                 Work        NaN                   1000       Hixson Pike
# 11     Personal errands        NaN                    800          McCallie
# 12                 Home        NaN                   5536    Old Mission Rd
# 13                 Home        NaN                   2020    Gunbarrel Road
# 14                Store        NaN                    NaN               NaN
# 15     Personal errands        NaN                    727  East 11th Street
# 16                 Home        NaN                    NaN               NaN
# 17     Personal errands        NaN                    NaN               NaN
# 18                 Home        NaN                    NaN               NaN
# 19                 Work        NaN                    NaN               NaN
# 20                 Work        NaN                    NaN               NaN
# 21                 Home        NaN                   2103             Daisy
# 22                 Home        NaN                    NaN           E. Main
# 23                 Home        NaN                   7356       Lee Hwy #37
# 24                 Work        NaN                    NaN         Gunbarrel
# 25                 Work        NaN                    NaN       E. Brainerd
# 26                Store        NaN                    NaN               NaN
# 27                 Home        NaN                   1201     Boynton Drive
# 28     Personal errands        NaN                    NaN               NaN
# 29                Store        NaN                    NaN               NaN
# ...                 ...        ...                    ...               ...
# 1855               Work        NaN                    209        Spears Ave
# 1856               Work        NaN                    NaN           Lee Hwy
# 1857               Home        NaN                   2605            Ivy St
# 1858              Store        NaN                    NaN        Near Sears
# 1859               Work        NaN                    NaN               NaN
# 1860               Home        NaN                    NaN      Sunrise Lane
# 1861               Home        NaN                   2626     Glenwood Pkwy
# 1862               Home        NaN                   5730       Lee Highway
# 1863               Work        NaN                    518        Central Dr
# 1864   Medical/hospital        NaN                    NaN               NaN
# 1865               Work        NaN                    NaN      McCallie Ave
# 1866               Home        NaN                    NaN           Lee Hwy
# 1867               Home        NaN                    602  West 14th Street
# 1868               Home        NaN                    959        Boynton Dr
# 1869               Home        NaN                    NaN               NaN
# 1870               Home        NaN      1709 Cambridge Dr               NaN
# 1871               Work        NaN  500 Highland Park Ave               NaN
# 1872               Home        NaN                     73  Shallowford Road
# 1873   Personal errands        NaN                   3806      Mission View
# 1874               Home        NaN                    686          E 8th St
# 1875               Home        NaN                    NaN               NaN
# 1876               Home        NaN                   1201        Boynton Dr
# 1877               Home        NaN                   1201        Boynton Dr
# 1878               Home        NaN                    NaN          Croll St
# 1879               Home        NaN                    NaN               NaN
# 1880               Home        NaN                    NaN               NaN
# 1881               Home        NaN                    390          Croll Ct
# 1882               Home        NaN                   1118             Fagan
# 1883               Home        NaN                   2329         E 5th Ave
# 1884  Social/restaurant        NaN                   3111       Wheeler Ave
#
#         Left Nearest Intersection                   Left Name  \
# 0                Campbell & Glass                         NaN
# 1              Riverside & Wilder                         NaN
# 2            Stuart & Chamberlain                         NaN
# 3                             NaN                         NaN
# 4       Tunnel Blvd & Shallowford                         NaN
# 5                  Main & Cypress             Howard, 25th St
# 6                 4th ave & Foust                         NaN
# 7                             NaN             Wal-Mart & Bank
# 8             Market St & 10th St        College Hills Courts
# 9                             NaN             East Lake Court
# 10         Falmouth & Hixson Pike  Across from Tremont Tavern
# 11                            NaN              Salvation Army
# 12      Old Mission & Brainerd Rd        Eastgate Town Center
# 13        Shallowford & Gunbarrel                     Walmart
# 14                            NaN                         NaN
# 15                 11th & Peeples           Community Kitchen
# 16                            NaN                         NaN
# 17                            NaN    Brown Academy Elementary
# 18                            NaN                         NaN
# 19                            NaN                         NaN
# 20                            NaN                      Amazon
# 21                  Dodds & Daisy                         NaN
# 22                            NaN               Wheeler Homes
# 23              Lee & Courage Way             Cedar Creek MHP
# 24                            NaN            Wilkins Research
# 25                            NaN                         NaN
# 26                            NaN                         NaN
# 27                  Boynton & MLK                         NaN
# 28                            NaN         Hamilton Place Mall
# 29                            NaN         Hamilton Place Mall
# ...                           ...                         ...
# 1855            Cherokee & Spears                         NaN
# 1856          Lee Hwy & Gunbarrel                         NaN
# 1857              Ivy & Greenwood                         NaN
# 1858                          NaN         Hamilton Place Mall
# 1859                 6th & Market                  Courthouse
# 1860        Brainerd & Germantown                         NaN
# 1861   McCallie & Brainerd Tunnel               McCallie High
# 1862           Lee Hwy & Brainerd                         NaN
# 1863                      Lee Hwy                     Enprize
# 1864                          NaN                         NaN
# 1865                          NaN             Mccallie School
# 1866        Shallowford & Lee Hwy                   Food City
# 1867   Main Street & College Hill                         NaN
# 1868  Georgia - Eward - Lightfoot                         NaN
# 1869                          NaN                         NaN
# 1870                          NaN                         NaN
# 1871                          NaN                         NaN
# 1872            Shallowford & Oak                   Apartment
# 1873     Belvoir and Mission view                         NaN
# 1874          University & 8th St         Decosimo Apartments
# 1875                          NaN                         NaN
# 1876        Boynton Dr & WML King         Boynton Terrace Apt
# 1877                          NaN         Boynton Terrace Apt
# 1878  Alton Park Blvd & W 33rd St                         NaN
# 1879                          NaN                         NaN
# 1880                          NaN                         NaN
# 1881            W 33rd & Croll Ct                         NaN
# 1882              42nd & Woodlawn                         NaN
# 1883                          NaN                         NaN
# 1884                          NaN                         NaN
#
#          Final Destination  ...                              Dest Name  \
# 0                     Work  ...                                    NaN
# 1                     Work  ...                                    NaN
# 2     University / College  ...                               Erlanger
# 3                     Work  ...                                    NaN
# 4         Personal errands  ...                                    NaN
# 5                     Work  ...                                    NaN
# 6                     Work  ...                                    NaN
# 7                      NaN  ...                                    NaN
# 8                     Work  ...                 Kentucky Fried Chicken
# 9         Personal errands  ...              East Gate Shopping Center
# 10                    Home  ...                             Home Depot
# 11     Social / restaurant  ...                            Aims Center
# 12        Personal errands  ...                          1st Tenn Bank
# 13        Personal errands  ...                                    NaN
# 14                    Work  ...                                    NaN
# 15                    Work  ...                      East Gate Library
# 16                    Work  ...                                    NaN
# 17                   Store  ...                                Walmart
# 18                   Store  ...                                    NaN
# 19                    Work  ...                                    NaN
# 20                    Home  ...                                    NaN
# 21                    Home  ...                                    NaN
# 22                    Home  ...                    Alton Park Villages
# 23                    Home  ...                        Cedar Group MHP
# 24                    Home  ...                                    NaN
# 25                    Home  ...                                    NaN
# 26                    Work  ...                              Acropolis
# 27                   Other  ...                          ODAR Building
# 28                   Store  ...                                Walmart
# 29        Personal errands  ...                                Walmart
# ...                    ...  ...                                    ...
# 1855                  Home  ...                                    NaN
# 1856                  Home  ...                                    NaN
# 1857                  Work  ...                                    NaN
# 1858                  Work  ...                                    NaN
# 1859                 Store  ...                     Walmart - Brainerd
# 1860                 Store  ...                         Hamilton Place
# 1861    Medical / Hospital  ...                          Erlanger East
# 1862      Personal errands  ...                                 Target
# 1863                 Store  ...                          First TN Bank
# 1864                 Other  ...                                    NaN
# 1865   Social / restaurant  ...                                Walmart
# 1866                  Work  ...             Hamilton County Courthouse
# 1867      Personal errands  ...                                    NaN
# 1868                  Home  ...                                    NaN
# 1869                  Work  ...                                    NaN
# 1870                  Home  ...                                    NaN
# 1871                  Work  ...                                    NaN
# 1872                  Work  ...  Moccasin Bend Mental Health Institute
# 1873      Personal errands  ...                                    NaN
# 1874  University / College  ...                   EMCS Building at UTC
# 1875    Medical / Hospital  ...                                    NaN
# 1876                 Other  ...                     Emma Wheeler Homes
# 1877                  Work  ...                                    NaN
# 1878                  Home  ...                                    NaN
# 1879         School (K-12)  ...                                    NaN
# 1880                  Work  ...                                    NaN
# 1881      Personal errands  ...                                    NaN
# 1882  University / College  ...          Chattanooga State East Campus
# 1883                  Work  ...                                    NaN
# 1884         School (K-12)  ...                                    NaN
#
#      Zipcode confidence_left   lat_left              lng_left confidence_dest  \
# 0      37406             9.0  35.072721           -85.240472              9.0
# 1      37406             9.0  35.076006   -85.25788779999999              NaN
# 2      37406             9.0  35.072284   -85.24194399999999              9.0
# 3      37406             9.0  35.040771   -85.25995370000001              9.0
# 4      37410             9.0  35.038021   -85.24016259999999              9.0
# 5      37402             9.0  35.026100   -85.30982499999999              9.0
# 6      37407             9.0  35.015280          -85.2802724              9.0
# 7        NaN             9.0  35.015511          -85.3764317              NaN
# 8      37402             9.0  35.042905          -85.3185582              9.0
# 9        NaN             9.0  35.012783          -85.2821192              9.0
# 10     37343             9.0  35.069547           -85.289513              9.0
# 11     37405             9.0  35.043263          -85.2954858              9.0
# 12     37414             9.0  35.008456          -85.2151665              9.0
# 13     37421             9.0  35.030159   -85.15277090000001              9.0
# 14       NaN             NaN        NaN                   NaN             NaN
# 15     37401             9.0  35.040600          -85.2999564              9.0
# 16     37406             NaN        NaN                   NaN             NaN
# 17     33401             9.0  35.043720          -85.2992616              9.0
# 18     37403             NaN        NaN                   NaN             NaN
# 19     37404             NaN        NaN                   NaN             9.0
# 20     37404             9.0  35.069041          -85.1411325              9.0
# 21       NaN             9.0  35.066890          -85.2543584              9.0
# 22     37403             9.0  34.991173   -85.30357339999999              9.0
# 23     37421             9.0  35.054373          -85.1443713              9.0
# 24     37411             9.0  35.022346          -85.1579513              9.0
# 25     37421             5.0  35.015369          -85.1119641              9.0
# 26     30736             NaN        NaN                   NaN             9.0
# 27     37402             9.0  35.045259          -85.3202049              9.0
# 28       NaN             9.0  35.033691          -85.1585253              9.0
# 29       NaN             9.0  35.033691          -85.1585253              9.0
# ...      ...             ...        ...                   ...             ...
# 1855   37403             9.0  35.064037           -85.310987              9.0
# 1856   37402             9.0  35.040573          -85.1684184              9.0
# 1857   37404             9.0  35.034255          -85.2615955              NaN
# 1858   37405             9.0  35.032960   -85.15923049999999              9.0
# 1859   37403             9.0  35.049291   -85.30897639999999              9.0
# 1860   37411             9.0  35.019032          -85.2531494              9.0
# 1861   37404             9.0  35.027877          -85.2626264              9.0
# 1862   37421             9.0  35.019116          -85.2023164              9.0
# 1863   37421             9.0  35.022961          -85.1952345              9.0
# 1864   37411             NaN        NaN                   NaN             9.0
# 1865     NaN             9.0  35.027877          -85.2626264              9.0
# 1866   37421             9.0  35.044696   -85.16430059999999              9.0
# 1867   37402             9.0  35.041275          -85.3167826              9.0
# 1868     NaN             9.0  35.046518           -85.320399              NaN
# 1869     NaN             NaN        NaN                   NaN             NaN
# 1870   37411             NaN        NaN                   NaN             NaN
# 1871   37411             NaN        NaN                   NaN             NaN
# 1872   37404             9.0  35.034493          -85.2572493              9.0
# 1873   37411             9.0  35.013983          -85.2463468              9.0
# 1874   37403             9.0  35.044100   -85.30142959999999              9.0
# 1875   37402             NaN        NaN                   NaN             NaN
# 1876   37402             9.0  35.045259          -85.3202049              9.0
# 1877   37402             9.0  35.045259          -85.3202049              9.0
# 1878     NaN             9.0  35.012331          -85.3110262              8.0
# 1879     NaN             NaN        NaN                   NaN             NaN
# 1880   37404             NaN        NaN                   NaN             NaN
# 1881   37410             9.0  35.011523           -85.311487              9.0
# 1882   37410             7.0  34.997907          -85.3118243              9.0
# 1883   37404             9.0  35.037095   -85.26673439999999              6.0
# 1884     NaN             9.0  35.072690          -85.2468373              NaN
#
#        lat_dest              lng_dest Geocode_result_left  Geocode_result_dest
# 0     35.000155          -85.2919233                 pass                 pass
# 1           NaN                   NaN                pass    insufficient_data
# 2     35.048552   -85.28950130000001                 pass                 pass
# 3     35.048697          -85.2902862                 pass                 pass
# 4     35.032369   -85.18462749999999                 pass                 pass
# 5     35.026521   -85.30909369999999                 pass                 pass
# 6     35.026521   -85.30909369999999                 pass                 pass
# 7           NaN                   NaN                pass    insufficient_data
# 8     35.039208           -85.266752                 pass                 pass
# 9     35.008456          -85.2151665                 pass                 pass
# 10    35.137361          -85.2435405                 pass                 pass
# 11    35.047488   -85.31796469999999                 pass                 pass
# 12    35.048276          -85.3103009                 pass                 pass
# 13    35.047544   -85.31689569999999                 pass                 pass
# 14          NaN                   NaN   insufficient_data    insufficient_data
# 15    35.008568          -85.2113813                 pass                 pass
# 16          NaN                   NaN   insufficient_data    insufficient_data
# 17    35.030159   -85.15277090000001                 pass                 pass
# 18          NaN                   NaN   insufficient_data    insufficient_data
# 19    35.030398          -85.2738976    insufficient_data                 pass
# 20    35.011722          -85.2806971                 pass                 pass
# 21    35.060205          -85.3089821                 pass                 pass
# 22    35.006690   -85.31099139999999                 pass                 pass
# 23    35.054285          -85.1452821                 pass                 pass
# 24    35.028407          -85.2441114                 pass                 pass
# 25    35.016211          -85.1873595              no_pass                 pass
# 26    35.039782   -85.15611299999999    insufficient_data                 pass
# 27    35.012395   -85.18959509999999                 pass                 pass
# 28    35.030159   -85.15277090000001                 pass                 pass
# 29    35.030159   -85.15277090000001                 pass                 pass
# ...         ...                   ...                 ...                  ...
# 1855  35.027297          -85.3169274                 pass                 pass
# 1856  35.041452   -85.31776579999999                 pass                 pass
# 1857        NaN                   NaN                pass    insufficient_data
# 1858  35.040793   -85.30788609999999                 pass                 pass
# 1859  35.008536          -85.2051089                 pass                 pass
# 1860  35.033691          -85.1585253                 pass                 pass
# 1861  35.022692          -85.1607872                 pass                 pass
# 1862  35.033380            -85.15979                 pass                 pass
# 1863  35.033380            -85.15979                 pass                 pass
# 1864  35.010657   -85.32079039999999    insufficient_data                 pass
# 1865  35.030159   -85.15277090000001                 pass                 pass
# 1866  35.049515   -85.30693099999999                 pass                 pass
# 1867  35.047118          -85.3094835                 pass                 pass
# 1868        NaN                   NaN                pass    insufficient_data
# 1869        NaN                   NaN   insufficient_data    insufficient_data
# 1870        NaN                   NaN   insufficient_data    insufficient_data
# 1871        NaN                   NaN   insufficient_data    insufficient_data
# 1872  35.047118          -85.3094835                 pass                 pass
# 1873  35.047488   -85.31796469999999                 pass                 pass
# 1874  35.046449          -85.2953357                 pass                 pass
# 1875        NaN                   NaN   insufficient_data    insufficient_data
# 1876  34.991173   -85.30357339999999                 pass                 pass
# 1877  35.065454           -85.311885                 pass                 pass
# 1878  35.045651           -85.320003                 pass                 pass
# 1879        NaN                   NaN   insufficient_data    insufficient_data
# 1880        NaN                   NaN   insufficient_data    insufficient_data
# 1881  35.049433          -85.2577719                 pass                 pass
# 1882  35.049836   -85.15342849999999              no_pass                 pass
# 1883  35.084789   -85.26222399999999                 pass              no_pass
# 1884        NaN                   NaN                pass    insufficient_data
#
# [1885 rows x 24 columns]

# %%
survey[['RespondentID', 'Route', 'Geocode_result_left']].pivot_table(
    columns=['Geocode_result_left'],
    index='Route',
    values='RespondentID',
    aggfunc='count',
    margins=True
).to_clipboard()

# %%
survey[['RespondentID', 'Route', 'Geocode_result_dest']].pivot_table(
    columns=['Geocode_result_dest'],
    index='Route',
    values='RespondentID',
    aggfunc='count',
    margins=True
).to_clipboard()

# %%
survey.to_csv(os.path.join('..', 'data', 'survey', '2015 on-board survey', 'survey_geocoded.csv'))
